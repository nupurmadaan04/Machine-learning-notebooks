# %% [markdown]
# <a href="https://colab.research.google.com/github/nupurmadaan04/Machine-learning-notebooks/blob/main/Outliers%20%2B%20feature%20scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")

# %% [markdown]
# OUTLIERS

# %%
# Step 1: find 25% and 75% values
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)

# Step 2: middle spread
IQR = Q3 - Q1

# Step 3: define safe range
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Step 4: keep only normal data
df = df[(df['Fare'] >= lower) & (df['Fare'] <= upper)]

# %%
# remove outliers
df = df[(df['Fare'] >= lower_bound) & (df['Fare'] <= upper_bound)]

# %%
from scipy import stats
import numpy as np

# Step 1: calculate z-score
z = np.abs(stats.zscore(df['Fare']))

# Step 2: keep only normal values
df = df[z < 3]

# %% [markdown]
# FEATURE SCALING

# %%
from sklearn.preprocessing import StandardScaler

# Create scaler object
scaler = StandardScaler()

# Apply standardisation on selected columns
# It converts data → mean = 0, std = 1
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# After this:
# data becomes centered around 0
# helps models that depend on distance

# %%
from sklearn.preprocessing import MinMaxScaler

# Create scaler object
scaler = MinMaxScaler()

# Apply normalization on selected columns
# It converts data → range between 0 and 1
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# After this:
# smallest value → 0
# largest value → 1
# all others scaled in between

# %%
# Standardisation:
# - mean = 0, std = 1
# - handles outliers better
# - used in ML algorithms like SVM, Logistic Regression

# Normalisation:
# - range = 0 to 1
# - sensitive to outliers
# - used in Neural Networks, image data
